# %% [markdown]
# <a href="https://colab.research.google.com/github/hxh00138/Physics-informed-neural-networks-for-solving-Reynolds-averaged-Navier-Stokes-equations/blob/master/PINN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/hxh00138/Physics-informed-neural-networks-for-solving-Reynolds-averaged-Navier-Stokes-equations.git
# Out:
# Cloning into 'Physics-informed-neural-networks-for-solving-Reynolds-averaged-Navier-Stokes-equations'...
# remote: Enumerating objects: 309, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 309 (delta 13), reused 8 (delta 8), pack-reused 288 (from 2)
# Receiving objects: 100% (309/309), 797.20 MiB | 36.75 MiB/s, done.
# Resolving deltas: 100% (113/113), done.
# Updating files: 100% (149/149), done.

# %%
# !ls
# !ls Physics-informed-neural-networks-for-solving-Reynolds-averaged-Navier-Stokes-equations
# Out:
# data
# error.py
# figs
# lbfgs.py
# models
# Physics-informed-neural-networks-for-solving-Reynolds-averaged-Navier-Stokes-equations
# PINN_phill.py
# postprocessing.py
# pred
# __pycache__
# train_configs.py
# train.py
# APG  FS  NACA4412  Periodic_Hill  Readme.md  ZPG

# %%
cd Physics-informed-neural-networks-for-solving-Reynolds-averaged-Navier-Stokes-equations/Periodic_Hill
# Out:
# /content/Physics-informed-neural-networks-for-solving-Reynolds-averaged-Navier-Stokes-equations/Periodic_Hill/Physics-informed-neural-networks-for-solving-Reynolds-averaged-Navier-Stokes-equations/Periodic_Hill

# %%
# !pip install pyDOE

# %%
# !python train.py
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch: 2748
# loss: 9.36481447e-05 loss_u: 5.89883966e-05 loss_f: 3.46597481e-05
# epoch: 2749
# loss: 9.36339711e-05 loss_u: 5.89537267e-05 loss_f: 3.46802444e-05
# epoch: 2750
# loss: 9.36214492e-05 loss_u: 5.89280644e-05 loss_f: 3.46933812e-05
# epoch: 2751
# loss: 9.35919234e-05 loss_u: 5.88975854e-05 loss_f: 3.4694338e-05
# epoch: 2752
# loss: 9.3553841e-05 loss_u: 5.89344236e-05 loss_f: 3.46194174e-05
# epoch: 2753
# loss: 9.35241696e-05 loss_u: 5.90128839e-05 loss_f: 3.45112894e-05
# epoch: 2754
# loss: 9.354145e-05 loss_u: 5.89747797e-05 loss_f: 3.45666704e-05
# epoch: 2755
# loss: 9.35137796e-05 loss_u: 5.89825577e-05 loss_f: 3.45312183e-05
# epoch: 2756
# loss: 9.34910931e-05 loss_u: 5.90234959e-05 loss_f: 3.44675973e-05
# epoch: 2757
# loss: 9.34780765e-05 loss_u: 5.9060756e-05 loss_f: 3.44173204e-05
# epoch: 2758
# loss: 9.34602867e-05 loss_u: 5.9097576e-05 loss_f: 3.43627071e-05
# epoch: 2759
# ...
